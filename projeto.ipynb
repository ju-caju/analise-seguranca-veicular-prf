# %%
import pandas as pd

# %%
colunas_andre = ['ano_base',
'arquivo_origem_enriquecido',
'id',
'pesid',
'data_inversa',
'dia_semana',
'horario',
'uf',
'br',
'km',
'municipio',
'causa_acidente',
'tipo_acidente',
'classificacao_acidente',
'fase_dia',
'sentido_via',
'condicao_metereologica',
'tipo_pista',
'tracado_via',
'uso_solo',
'id_veiculo',
'tipo_veiculo',
'marca',
'ano_fabricacao_veiculo',
'tipo_envolvido',
'estado_fisico',
'idade',
'sexo',
'nacionalidade',
'naturalidade',
]

# %%
dataframe = pd.read_csv(
    'acidentes_2010_2026_carros_latin_ncap.csv',
    usecols = colunas_andre,
    sep = ';',
    dtype = str
    )

# %%
for colunas in colunas_andre:
    print(colunas, '->', dataframe[colunas].dropna().unique()[:5])
# Out:
# ano_base -> ['2010' '2011' '2012' '2013' '2014']
# arquivo_origem_enriquecido -> ['prf_analise/data/processed/multiyear/final_by_year/2010/acidentes_enriquecido.csv'
#  'prf_analise/data/processed/multiyear/final_by_year/2011/acidentes_enriquecido.csv'
#  'prf_analise/data/processed/multiyear/final_by_year/2012/acidentes_enriquecido.csv'
#  'prf_analise/data/processed/multiyear/final_by_year/2013/acidentes_enriquecido.csv'
#  'prf_analise/data/processed/multiyear/final_by_year/2014/acidentes_enriquecido.csv']
# id -> ['636034' '636090' '636207' '636220' '636267']
# pesid -> ['1906759' '1907083' '1907180' '1907185' '1907188']
# data_inversa -> ['01/01/2010' '02/01/2010' '03/01/2010' '04/01/2010' '05/01/2010']
# dia_semana -> ['Sexta  ' 'Sábado ' 'Domingo' 'Segunda' 'Terça  ']
# horario -> ['03:00:00' '08:00:00' '12:10:00' '13:05:00' '05:50:00']
# uf -> ['SC' 'MG' 'PA' 'RO' 'PR']
# br -> ['282' '116' '316' '364' '277']
# km -> ['1.5' '486.8' '25' '704.8' '298.3']
# ...
